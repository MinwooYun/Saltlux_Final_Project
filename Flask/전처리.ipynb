# %%
text = '유엔 인권전문가 "형법으로 낙태 처벌하는 한국 우려" \n유엔 인권이사회 산하 전문가들이 한국 정부의 낙태 처벌 관련 개정안에 우려를 표했다.\xa0\n여성차별 실무위원회와 건강권 특별보고관, 여성폭력 특별보고관은 1일(현지시간) "낙태 규제를 위해 형법을 계속해 사용하는 점을 우려한다"면서 "우리는 여성이 임신 중절로 절대 형사 처벌돼서는 안된다는 바를 상기하고자 한다"고 밝혔다.\n또 "국제인권 규범에 따라 임신 중절을 범죄로 여기지 않는 데 필요한 조처와 합법적이고 안전한 낙태 서비스에 대한 접근권을 보장하는 조처를 촉구한다"고 강조했다.\xa0\n그러면서 "합법적 임신 중절에 대한 접근에 있어 대기 기간, 의무 상담과 같은 의료적 필요에 근거하지 않은 차별적 장애물을 제거하라"고 권고했다.\xa0\n앞서 헌법재판소는 2019년 4월 낙태죄에 대해 헌법 불합치 결정을 내리면서 현행 형법은 지난해 말까지 개정돼야 한다고 주문했다. 이에 따라 정부는 지난해 10월 임신 14주 이내에서는 낙태를 허용하는 내용의 형법·모자보건법 개정안을 발의했다.\xa0\n하지만 국회에 계류중이라 대체 법률 미비로 낙태에 대한 형사 처벌을 규정한 형법 조항은 지난해 12월31일부로 효력을 상실했다.\xa0\n이보배 한경닷컴 객원기자 newsinfo@hankyung.com\nⓒ 한국경제 & , 무단전재 및 재배포 금지\n'

'이란, 솔레이마니 사망 1주기 앞두고 보복 다짐 \n이란 국영 IRNA 통신에 따르면 에브라힘 라이시 이란 사법부 수장은 현지 시간으로 1일 "솔레이마니 살해범에게 안전한 곳은 어디에도 없을 것"이라고 말했습니다.\n라이시 사법부 수장은 "미군을 완전히 철수시키고 극악무도한 암살범을 재판에 회부하는 것이 솔레이마니 암살에 대한 가혹한 복수가 될 것"이라고 강조했습니다.\n이어 "원수들은 이제 매우 힘든 삶을 살게 될 것"이라며 "마지막 보복을 기다리게 될 것"이라고 덧붙였습니다.\n솔레이마니의 뒤를 이어 쿠드스군 사령관 직을 맡은 에스마일 가니 역시 "적의 집 안에서 그들의 범죄에 복수할 누군가가 나타날 것"이라며 보복을 다짐했습니다.\n이어 "이란은 언제나 미국에 대응할 준비가 돼 있다"며 "미국의 장난이 쿠드스군의 저항을 막지는 못할 것"이라고 덧붙였습니다.\n솔레이마니 전 사령관은 지난해 1월 3일 이라크 바그다드에서 미군의 무인기 공격을 받아 사망했습니다.\n그는 이란-이라크 전쟁 당시 사단장으로서 혁혁한 공을 세워 명성을 얻은 뒤 지난 1998년 쿠드스군 총사령관에 임명됐습니다.\n이란에서는 영웅 대접을 받았으며, 선출직 대통령보다 쿠드스군의 수장인 솔레이마니가 최고지도자 알리 하메네이 다음 \'2인자\'에 가깝다고 보는 시각도 존재했습니다.\n그러나 미국과 이스라엘은 쿠드스군을 테러리즘 지원의 핵심으로 여기고 그의 제거를 노려왔습니다.\n(사진=연합뉴스)\n안상우 기자asw@sbs.co.kr\n'

'\'1056억 증발?\'.. "첼시, 근처에 그릴리쉬라는 좋은 해결책 있었는데" \n[스포탈코리아] 허윤수 기자= 첼시의 카이 하베르츠(21) 영입은 이렇게 실패한 투자가 될까.\n지난 시즌 하베르츠는 맹활약을 펼치며 첼시의 눈을 사로잡았다. 독일 분데스리가 레버쿠젠 소속으로 45경기에 나서 18골 9도움으로 빛났다.\n첼시가 빠르게 접근했다. 7,100만 파운드(약 1,056억 원)를 투자해 하베르츠를 품었다. 하지만 높은 기대와 달리 좀처럼 적응하지 못하고 있다. 리그 14경기 1골 2도움이 전부.\n그러자 최고의 활약을 펼치고 있는 잭 그릴리쉬(애스턴 빌라)와 비교도 시작됐다. 올 시즌 그릴리쉬는 리그 14경기 5골 8도움으로 에이스 역할을 톡톡히 하고 있다.\n‘풋볼 런던’은 지난달 31일(한국시간) 첼시에서 활약했던 크레이그 벌리의 말을 빌려 “공격력 향상을 노렸던 프랭크 램파드 감독은 근처에 있던 더 좋은 해결책을 간과했다”라고 전했다.\n벌리는 “그릴리쉬 영입을 반대하지 않았을 것이다. 그는 다시 최고의 모습과 함께 환상적인 시즌을 보내고 있다. 모든 것을 갖췄다”라며 그릴리쉬의 기량을 극찬했다.\n이어 “현재 하베르츠는 길을 잃었고 티모 베르너는 자신감을 상실했다”라고 덧붙였다.\n그는 “그릴리쉬는 모든 걸 할 수 있는 미드필더다. 그는 하베르츠보다 더 많은 전술 옵션을 제공했을 것이다”라며 다재다능함을 말했다.\n사진=게티이미지코리아  취재문의 sportal@sportalkorea.co.kr | Copyright ⓒ 스포탈코리아. 무단전재 및 재배포 금지\n'

"오늘부터 '제주특별자치도경찰청'으로 명칭 변경 [KBS 제주]제주지방경찰청 명칭이 오늘(1일)부터 ‘제주특별자치도경찰청’으로 변경됐습니다.\n명칭 변경은 지난 1991년 제주도경찰국에서 제주지방경찰청으로 승격된 이후 30년 만으로, 개정된 ‘국가경찰과 자치경찰 조직과 운영에 관한 법률’ 시행에 따른 것입니다.\n개정 경찰법 시행으로 자치경찰에 파견한 국가경찰 268명도 모두 복귀하고, 자치경찰이 수행하던 일부 생활안전과 교통 분야 사무도 다시 국가경찰이 맡게 됐습니다.\n안서연 기자 (asy0104@kbs.co.kr)\n"
# Out:
# "오늘부터 '제주특별자치도경찰청'으로 명칭 변경 [KBS 제주]제주지방경찰청 명칭이 오늘(1일)부터 ‘제주특별자치도경찰청’으로 변경됐습니다.\n명칭 변경은 지난 1991년 제주도경찰국에서 제주지방경찰청으로 승격된 이후 30년 만으로, 개정된 ‘국가경찰과 자치경찰 조직과 운영에 관한 법률’ 시행에 따른 것입니다.\n개정 경찰법 시행으로 자치경찰에 파견한 국가경찰 268명도 모두 복귀하고, 자치경찰이 수행하던 일부 생활안전과 교통 분야 사무도 다시 국가경찰이 맡게 됐습니다.\n안서연 기자 (asy0104@kbs.co.kr)\n"

# %%
text
# Out:
# '유엔 인권전문가 "형법으로 낙태 처벌하는 한국 우려" \n유엔 인권이사회 산하 전문가들이 한국 정부의 낙태 처벌 관련 개정안에 우려를 표했다.\xa0\n여성차별 실무위원회와 건강권 특별보고관, 여성폭력 특별보고관은 1일(현지시간) "낙태 규제를 위해 형법을 계속해 사용하는 점을 우려한다"면서 "우리는 여성이 임신 중절로 절대 형사 처벌돼서는 안된다는 바를 상기하고자 한다"고 밝혔다.\n또 "국제인권 규범에 따라 임신 중절을 범죄로 여기지 않는 데 필요한 조처와 합법적이고 안전한 낙태 서비스에 대한 접근권을 보장하는 조처를 촉구한다"고 강조했다.\xa0\n그러면서 "합법적 임신 중절에 대한 접근에 있어 대기 기간, 의무 상담과 같은 의료적 필요에 근거하지 않은 차별적 장애물을 제거하라"고 권고했다.\xa0\n앞서 헌법재판소는 2019년 4월 낙태죄에 대해 헌법 불합치 결정을 내리면서 현행 형법은 지난해 말까지 개정돼야 한다고 주문했다. 이에 따라 정부는 지난해 10월 임신 14주 이내에서는 낙태를 허용하는 내용의 형법·모자보건법 개정안을 발의했다.\xa0\n하지만 국회에 계류중이라 대체 법률 미비로 낙태에 대한 형사 처벌을 규정한 형법 조항은 지난해 12월31일부로 효력을 상실했다.\xa0\n이보배 한경닷컴 객원기자 newsinfo@hankyung.com\nⓒ 한국경제 & , 무단전재 및 재배포 금지\n'

# %%
import re
# -*- coding: utf-8 -*-

def clean_text(inputString):
    text_rmv = re.sub('[-=+,#/\?:^.@*\"※~ㆍ!』‘|\(\)\[\]`\'…》\”\“\’·]', ' ', str(inputString))
    text_rmv = ' '.join(text_rmv.split())
    return text_rmv


# df['detail'] = df['detail'].apply(clean_text)

# %%
import time
from tqdm import tqdm

def tagger_time(tagger, texts):
  time_sum = 0

  for sentence in tqdm(texts):
    t1 = time.time()
    try:
      tagger.morphs(sentence)
    except:
      pass
    t2 = time.time()

    time_sum += (t2 - t1)

  return time_sum
texts = train['document'][:10000]
time_list = []

for tagger in [kkm, kom, okt, mec]:
  time_list.append(tagger_time(tagger, texts))
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

tagger = ['Kkma', 'Komoran', 'Okt', 'Mecab']

plt.figure(figsize=(10,8))
plt.bar(tagger, time_list, color=(0.4,0.7,0.5))
plt.title('Learning Time for 10000 reviews', fontsize=17)
plt.xticks(fontsize=14)
plt.ylabel('total seconds')

# %%
import pandas as pd
from datetime import datetime, timedelta 

df = pd.DataFrame(columns=['title', 'press','date','link','img','category','detail'])
# 시작일,종료일 설정 
start = "20210101" 
last = "20210331" 
# 시작일, 종료일 datetime 으로 변환 
start_date = datetime.strptime(start, "%Y%m%d") 
last_date = datetime.strptime(last, "%Y%m%d") 
# 종료일 까지 반복 
while start_date <= last_date: 
    dates = start_date.strftime("%Y%m%d") 
    filename = dates + 'crawling.csv'
    data = pd.read_csv("news data\\" + filename)
    df = pd.concat([df,data])
    print(dates) 
    # 하루 더하기 
    start_date += timedelta(days=1)

df.to_csv('2021_1.csv',index=False,encoding= 'utf-8-sig')
# Out:
# 20210101
# 20210102
# 20210103
# 20210104
# 20210105
# 20210106
# 20210107
# 20210108
# 20210109
# 20210110
# 20210111
# 20210112
# 20210113
# 20210114
# 20210115
# 20210116
# 20210117
# 20210118
# 20210119
# 20210120
# 20210121
# 20210122
# 20210123
# 20210124
# 20210125
# 20210126
# 20210127
# 20210128
# 20210129
# 20210130
# 20210131
# 20210201
# 20210202
# 20210203
# 20210204
# 20210205
# 20210206
# 20210207
# 20210208
# 20210209
# 20210210
# 20210211
# 20210212
# 20210213
# 20210214
# 20210215
# 20210216
# 20210217
# 20210218
# 20210219
# 20210220
# 20210221
# 20210222
# 20210223
# 20210224
# 20210225
# 20210226
# 20210227
# 20210228
# 20210301
# 20210302
# 20210303
# 20210304
# 20210305
# 20210306
# 20210307
# 20210308
# 20210309
# 20210310
# 20210311
# 20210312
# 20210313
# 20210314
# 20210315
# 20210316
# 20210317
# 20210318
# 20210319
# 20210320
# 20210321
# 20210322
# 20210323
# 20210324
# 20210325
# 20210326
# 20210327
# 20210328
# 20210329
# 20210330
# 20210331

# %%
df = pd.read_csv("2021_1.csv")
df.shape
# Out:
# (405000, 7)

# %%
import pandas as pd

# %%
from konlpy.tag import Mecab
import numpy as np

mecab = Mecab(dicpath=r"C:\mecab\mecab-ko-dic")

text_pos_list = mecab.pos(text)
text_noun_list = [i[0] for i in text_pos_list if i[1] == 'NNP' or i[1] == 'NNG']

text_noun_count = {}
text_count = np.unique(text_noun_list, return_counts=True)

for noun, count in zip(*text_count):
    text_noun_count[noun] = count

text_noun_count = sorted(text_noun_count.items(), key=lambda x: x[1], reverse=True)

text_noun_count
# Out:
# [('낙태', 6),
#  ('형법', 5),
#  ('임신', 4),
#  ('처벌', 4),
#  ('여성', 3),
#  ('우려', 3),
#  ('인권', 3),
#  ('지난해', 3),
#  ('한국', 3),
#  ('개정안', 2),
#  ('유엔', 2),
#  ('전문가', 2),
#  ('정부', 2),
#  ('조처', 2),
#  ('차별', 2),
#  ('특별', 2),
#  ('필요', 2),
#  ('합법', 2),
#  ('헌법', 2),
#  ('형사', 2),
#  ('강조', 1),
#  ('개정', 1),
#  ('객원', 1),
#  ('건강', 1),
#  ('결정', 1),
#  ('경제', 1),
#  ('계류', 1),
#  ('계속', 1),
#  ('관', 1),
#  ('관련', 1),
#  ('관은', 1),
#  ('국제', 1),
#  ('국회', 1),
#  ('권고', 1),
#  ('규범', 1),
#  ('규정', 1),
#  ('규제', 1),
#  ('근거', 1),
#  ('금지', 1),
#  ('기간', 1),
#  ('기자', 1),
#  ('낙태죄', 1),
#  ('내용', 1),
#  ('닷컴', 1),
#  ('대기', 1),
#  ('모자', 1),
#  ('무단', 1),
#  ('미비', 1),
#  ('발의', 1),
#  ('배포', 1),
#  ('범죄', 1),
#  ('법', 1),
#  ('법률', 1),
#  ('보건', 1),
#  ('보장', 1),
#  ('사용', 1),
#  ('사회', 1),
#  ('산하', 1),
#  ('상기', 1),
#  ('상담', 1),
#  ('상실', 1),
#  ('서비스', 1),
#  ('시간', 1),
#  ('실무', 1),
#  ('안전', 1),
#  ('위원회', 1),
#  ('의료', 1),
#  ('의무', 1),
#  ('이내', 1),
#  ('이보배', 1),
#  ('일부', 1),
# ...

# %%
text_nouns = mecab.nouns(text)
text_nouns
# Out:
# ['유엔',
#  '인권',
#  '전문가',
#  '형법',
#  '낙태',
#  '처벌',
#  '한국',
#  '우려',
#  '유엔',
#  '인권',
#  '사회',
#  '산하',
#  '전문가',
#  '한국',
#  '정부',
#  '낙태',
#  '처벌',
#  '관련',
#  '개정안',
#  '우려',
#  '여성',
#  '차별',
#  '실무',
#  '위원회',
#  '건강',
#  '특별',
#  '관',
#  '여성',
#  '폭력',
#  '특별',
#  '관은',
#  '일',
#  '현지',
#  '시간',
#  '낙태',
#  '규제',
#  '형법',
#  '계속',
#  '사용',
#  '점',
#  '우려',
#  '우리',
#  '여성',
#  '임신',
#  '중',
#  '형사',
#  '처벌',
#  '바',
#  '상기',
#  '국제',
#  '인권',
#  '규범',
#  '임신',
#  '중절',
#  '범죄',
#  '데',
#  '필요',
#  '조처',
#  '합법',
#  '안전',
#  '낙태',
#  '서비스',
#  '접근권',
#  '보장',
#  '조처',
#  '촉구',
#  '강조',
#  '합법',
#  '임신',
#  '중',
#  '절',
#  '접근',
#  '대기',
#  '기간',
#  '의무',
#  '상담',
#  '의료',
#  '필요',
#  '근거',
#  '차별',
#  '장애물',
#  '제거',
#  '권고',
#  '헌법',
#  '재판소',
#  '년',
#  '월',
#  '낙태죄',
#  '헌법',
#  '합치',
#  '결정',
#  '현행',
#  '형법',
#  '지난해',
#  '말',
#  '개정',
#  '주문',
#  '이',
#  '정부',
#  '지난해',
#  '월',
#  '임신',
#  '주',
#  '이내',
#  '낙태',
#  '허용',
#  '내용',
#  '형법',
#  '모자',
#  '보건',
#  '법',
# ...

# %%
import pandas as pd

df = pd.read_csv("20210301crawling.csv")

def pre_processing_db(df) : 
    from konlpy.tag import Mecab
    import numpy as np
    import pandas as pd
    # 영어 기사 제거
    df['td']=df['title']+' '+df['detail']
    df_kor = df[df['td'].str.contains('[|가-힣]')==True]
    df_kor = df_kor.reset_index().drop(columns = ['index','link'], axis=1)
    #카테고리 그룹화 
    final_category = ['문화', '스포츠', '연예']
    cate = [['영화'], ['해외축구', '배구', '농구', '축구', 'e스포츠', '야구', '골프', '해외야구'], 
            ['예능', '방송', '연예일반', '드라마', '연예가화제', '가요음악']]
    f_start_idx = 0
    i_start_idx = 0
    for category in range(f_start_idx, len(final_category)):
        f_start_idx += 1
        for item in range(i_start_idx, len(cate)) :
            df_kor['category'].replace(cate[item], final_category[category], inplace=True)
            i_start_idx += 1
            break
    # nouns 컬럼 생성
    mecab = Mecab(dicpath=r"C:\mecab\mecab-ko-dic")
    noun_list = []
    for i in range(len(df_kor)) : 
        text = df_kor['td'][i]
        text_pos_list = mecab.pos(text)
        text_noun_list = [i[0] for i in text_pos_list if i[1] == 'NNP' or i[1] == 'NNG']

        noun_str =' '.join(text_noun_list)
        noun_list.append(noun_str)

    df_kor['noun']=noun_list
    df_kor = df_kor.drop(columns = 'td', axis=1)
    return df_kor

pre_processing_db(df)
# Out:
#                                               title   press  \
# 0        박지훈 변호사, "증거 법정서 기성용에게 전달, 피해자에게 소송 제기해달라"  스포탈코리아
# 1            '동상이몽2' 오지영, 은보아에 "송창의, 술친구 집에 데려와" 토로     뉴스1
# 2                 한고은 "삼겹살 안 먹어, 지방 못 삼키겠다" (동상이몽2)  티브이데일리
# 3                               美 뉴욕 증시 3대 지수 상승 출발    조선일보
# 4                     최예빈, 학폭 부인..'펜트하우스' 하은별役 [전문]   MBC연예
# ...                                             ...     ...
# 3804                                      [인사] 중앙그룹    중앙일보
# 3805                       [인사] 조광제 서울미디어대학원대학교 이사장    중앙일보
# 3806            3월 첫날, 중부 최대 100mm 봄비..3월 2일 출근길 혼잡    데일리안
# 3807           '손흥민 리그 7호 도움' 토트넘, 번리전 전반 3-0 리드 종료   MK스포츠
# 3808  인터넷가입 비교사이트 '정당함', KT SK LG IPTV 결합상품 당일 현금지원    데일리안
#
#                      date                                                img  \
# 0     2021. 03. 01. 23:48  https://img3.daumcdn.net/thumb/R658x0.q70/?fna...
# 1     2021. 03. 01. 23:48  https://img1.daumcdn.net/thumb/R658x0.q70/?fna...
# ...

# %%
df.to_csv("sample.csv")

# %%
from datetime import datetime, timedelta

# %%
df['date'] = df['date'].apply(lambda _: datetime.strptime(_,"%Y. %m. %d. %H:%M"))

# %%
idx = df[df['date'] == 'Null'].index
df = df.drop(idx)

# %%
df.head()
# Out:
#                                         title   press                date  \
# 0  박지훈 변호사, "증거 법정서 기성용에게 전달, 피해자에게 소송 제기해달라"  스포탈코리아 2021-03-01 23:48:00
# 1      '동상이몽2' 오지영, 은보아에 "송창의, 술친구 집에 데려와" 토로     뉴스1 2021-03-01 23:48:00
# 2           한고은 "삼겹살 안 먹어, 지방 못 삼키겠다" (동상이몽2)  티브이데일리 2021-03-01 23:47:00
# 3                         美 뉴욕 증시 3대 지수 상승 출발    조선일보 2021-03-01 23:46:00
# 4               최예빈, 학폭 부인..'펜트하우스' 하은별役 [전문]   MBC연예 2021-03-01 23:46:00
#
#                                      link  \
# 0  https://v.daum.net/v/20210301234841923
# 1  https://v.daum.net/v/20210301234839922
# 2  https://v.daum.net/v/20210301234719921
# 3  https://v.daum.net/v/20210301234658920
# 4  https://v.daum.net/v/20210301234640919
#
#                                                  img  \
# 0  https://img3.daumcdn.net/thumb/R658x0.q70/?fna...
# 1  https://img1.daumcdn.net/thumb/R658x0.q70/?fna...
# 2  https://img4.daumcdn.net/thumb/R658x0.q70/?fna...
# ...
